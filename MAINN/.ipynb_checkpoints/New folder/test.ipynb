# %%
import numpy as np
import pandas as pd

# %%
print(5)
# Out:
# 5

# %%
df = pd.read_csv(r"D:\cgpa_iq_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1132006933.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(r"D:\cgpa_iq_dataset.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
# !nividia-smi
# Out:
# /bin/bash: line 1: nividia-smi: command not found

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import os, sys, platform
from pathlib import Path
print('Platform:', platform.system(), platform.release(), platform.machine())
print('os.name:', os.name)
print('Python executable:', sys.executable)
print('Current working directory:', os.getcwd())
print('Notebook file path (cwd) listing:')
for p in Path('.').resolve().iterdir():
    print('-', p)
test_path = Path(r'D:\\cgpa_iq_dataset.csv')
print('Does D:\\cgpa_iq_dataset.csv exist from kernel?', test_path.exists())
print('Also check relative file in notebook folder (cgpa_iq_dataset.csv):', Path('cgpa_iq_dataset.csv').exists())
print('\nIf the kernel is running on Linux (e.g. platform.system() == "Linux"), Windows drive letters like D: are not available to the kernel.\n')
# Out:
# Platform: Linux 6.6.105+ x86_64
# os.name: posix
# Python executable: /usr/bin/python3
# Current working directory: /content
# Notebook file path (cwd) listing:
# - /content/.config
# - /content/sample_data
# Does D:\cgpa_iq_dataset.csv exist from kernel? False
# Also check relative file in notebook folder (cgpa_iq_dataset.csv): False
#
# If the kernel is running on Linux (e.g. platform.system() == "Linux"), Windows drive letters like D: are not available to the kernel.

# %%
Copy-Item -Path 'D:\cgpa_iq_dataset.csv' -Destination 'F:\SEM 5\ML\CA2\MEDICARE\MAINN\'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipython-input-2299284249.py:1: SyntaxWarning: invalid escape sequence '\c'
#   Copy-Item -Path 'D:\cgpa_iq_dataset.csv' -Destination 'F:\SEM 5\ML\CA2\MEDICARE\MAINN\'
#   File "/tmp/ipython-input-2299284249.py", line 1
#     Copy-Item -Path 'D:\cgpa_iq_dataset.csv' -Destination 'F:\SEM 5\ML\CA2\MEDICARE\MAINN\'
#                                                           ^
# SyntaxError: unterminated string literal (detected at line 1)
